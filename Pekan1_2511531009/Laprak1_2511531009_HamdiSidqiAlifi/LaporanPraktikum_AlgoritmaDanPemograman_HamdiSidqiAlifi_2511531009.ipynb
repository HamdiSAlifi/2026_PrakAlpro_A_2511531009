# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORTIMA DAN PEMOGRAMAN**
#
# **“Pengenalan Pemograman”**
#
# **Disusun Oleh :**
#
# **Hamdi Sidqi Alifi**
#
# **2511531009**
#
# **Dosen Pengampu:**
#
# **Ph.D. Ir. Wahyudi, S.T., M.T.**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Avero**
#
# <br>
#
#  <img src="images/Logo_Unand.svg" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum Algortima dan Pemograman yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Struktur Data. Praktikum ini berfokus pada pembahasan Python environment, Code Editor dan git environtment.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep pemograman awal pada python sehingga menjadi penonjang pennulis pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Pada saat modern ini zamaan semakin canggih. Oleh karena itu, sebagai mahasiswa informatika, sudah seharusnya kita memahami bidang yang sepatutnya kita dalami yaitu Informatika.
#
# Di dalam informatika kita harus mengenal yang namanya pemograman, dan pastinya pemograman harus selalu disandingkan dengan algortima. Sehingga diampulah oleh mahasiswa informatika sebuah mata kuliah dengan nama Algoritma dan Pemograman.
#
# Terdapat banyak cara untuk mempelajari algoritma, salah satunya adalah dengan mempelajari bahasa bahasa pemograman yang memiliki logic logic yang jelas, salah satunya yaitu Bahasa Pemograman Python, tidak hnaya jelas, Python juga merupakan salah satu bahasa pemograman yang mudah untuk dimengerti jika kita sudah memahami beberapa aturan matematika.
#
# ## 1.2 Tujuan
# 1. Mengenal apa itu pemograman
# 2. Mampu menuliskan sebuah pemograman
# 3. Mengenal beberapa baris sederhana di Python
#
# ## 1.3 Manfaat
# 1. Mampu menuliskan sebuah program
# 2. Mampu menjalankan sebuah program

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Beberapa dasar teori yang meliputi paraktikum ini adaalh:
#
# 1. Fungsi print(): Untuk menampilkan pesan atau data ke layar. Pemamnggilan print() tanpa argumen akan mencetak baris kosong.
# 2. Komentar dalam Python: Catatan pada kode tanpa mengacaukan logika kode.
# 3. String concat & Escape char: concat adalah metode untuk emnggabungkan string, backlash jika ditautkan denagn huruf khusus seperti n akan menghasilkan sebuah fungsi tertentu, \n menghasilkan newline.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "NamaKelas_NIM"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Program Pertama

"""
Komentar
dua baris atau lebih
pertemuan 1 praktikum alpro
"""

print("Hello World")
print()
print("Program ini menghasilan")
print("Empat baris output")
print("/ \\ // \\\\ /// \\\\\\")
print("program ini " + "dibuat an. " + "Hamdi Sidqi Alifi", "2511531009")
# Out:
# Hello World
#
# Program ini menghasilan
# Empat baris output
# / \ // \\ /// \\\
# program ini dibuat an. Hamdi Sidqi Alifi 2511531009

# %% [markdown]
# Hello World
#
# Program ini menghasilkan
# Empat baris output
# /\//\\///\\\
# program ini dibuat oleh a
# Hamdi Sidqi Alifi dan 2511531009.

# %% [markdown]
# **Penjelasan :**
# 1. //#Program pertama... dan """Komentar...""" hanya untuk komentar saja
# 2. print("Hello World") untuk menccetak pesan Hello World
# 3. print() mencetak baris kosong
# 4. begitu pula dengan print("Program ini menghasilkan") dan print("Empat baris output")
# 5. print("program ini " + "dibuat an. " + "Hamdi Sidqi Alifi", "2511531009") memiliki pengaplikasian concatenation yang ditandai dengana danya + dan koma (,)

# %% [markdown]
# ---
# ## 2.3 Tugas : Membuat program bebas python

# %%
# Tugas : Program Bebas
Nama_1009    = "Hamdi Sidqi Alifi"
NIM_1009     = "2511531009"
Jurusan_1009 = "Informatika"

print("Nama_1009 : ", Nama_1009, ", NIM_1009 : ", NIM_1009, ", Jurusan : ", Jurusan_1009)
# Out:
# Nama_1009 :  Hamdi Sidqi Alifi , NIM_1009 :  2511531009 , Jurusan :  Informatika

# %% [markdown]
# Output yang akan dihasilkan ialah
#
# ```
# Nama_1009 :  Hamdi Sidqi Alifi , NIM_1009 :  2511531009 , Jurusan :  Informatika
# ```

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa fungsi print() berguna untuk mencetak pesan ke layar, dan adanya # dan """""" memudahkan kita untuk mendokumentasikan kode kode kita.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
#
# DAFTAR PUSTAKA
# [1] W3Schools, "Python Comments," W3Schools. [Online]. Tersedia: https://www.w3schools.com/python/python_comments.asp [Diakses tanggal 07-09-2026].
#
# [2] GeeksforGeeks, "Python Output using print() function," GeeksforGeeks, 2023. [Online]. Tersedia: https://www.geeksforgeeks.org/python-output-using-print-function/ [Diakses tanggal 07-09-2026].
